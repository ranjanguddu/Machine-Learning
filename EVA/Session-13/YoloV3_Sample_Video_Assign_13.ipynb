# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjanguddu/Machine-Learning/blob/master/EVA/Session-13/YoloV3_Sample_Video_Assign_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Cloning the GIT-HUB Project**

# %%
# !git clone https://github.com/theschoolofai/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 139 (delta 1), reused 139 (delta 1), pack-reused 0
# Receiving objects: 100% (139/139), 10.46 MiB | 16.33 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %% [markdown]
# **Mount the Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive')

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
ls
# Out:
# '2013-01-30 16.35.06 (1).jpg'
#  4854XXXXXXXXXX45_12-10-2018.PDF
#  50801943_DOC1.pdf
#  75071054_T.DOC
# 'apiit-alumni-bangalore (1).gsheet'
#  apiit-alumni-bangalore.gsheet
#  Classroom/
# 'Colab Notebooks'/
# 'Copy of 2d-overfitting-18May.pptx'
# 'Copy of PatientResponse.xlsx'
# 'Copy of yolov3-spp-ultralytics.pt'
# 'crash questions.gsheet'
#  EVA4_Assignment/
# 'HOUSE Expense.gsheet'
# 'iipuc_phy (1).gsheet'
#  iipuc_phy.gsheet
#  INV-KA-B1-11831379-102015482916-MAY-2019.html
#  MarkSheet_service.png
# 'padu 3.jpg'
#  Scan_MTech_Degree.pdf
# 'sfr_status (1).gsheet'
#  sfr_status.gsheet
# "SIA-Report-Donaught Form-March'19.xlsx"
#  ToDoList.gsheet
#  Tut--Khata.gsheet
# 'Untitled document.gdoc'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet.gsheet'
#  Vikash/
#  Vikash_Resume_for_Teaching_Hash_Learning.docx
#  VinayResume.pdf
#  YoloV3/

# %%
cd YoloV3/
# Out:
# /content/drive/My Drive/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  runs		   utils
#  cfg		   __pycache__	  test.py	   vim.exe.stackdump
#  data		   README.md	  ting		   weights
#  detect.py	   results.json   train.py
#  models.py	   results.png	 'ubdivisions=1'

# %% [markdown]
# **Train the  Model for 300 epochs on the 500 shinchan images.**
# **Those images are kept in customdata folder within data folder of the clonned YoloV3 project**

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-04-24 14:53:51.522594: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (479 found, 0 missing, 18 empty, 0 duplicate, for 497 images): 100% 497/497 [00:55<00:00,  9.00it/s]
# Caching images (0.3GB): 100% 497/497 [05:13<00:00,  1.59it/s]
# Reading image shapes: 100% 497/497 [00:00<00:00, 1028.99it/s]
# ...

# %% [markdown]
# **Applied the trained imaged on the short clip of shinchan and stord the data in out_out folder**

# %%
! python detect.py --source shinchan.mp4 --conf-thres 0.1 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='shinchan.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/903) shinchan.mp4: 320x512 1 shinchans, Done. (0.034s)
# video 1/1 (2/903) shinchan.mp4: 320x512 1 shinchans, Done. (0.033s)
# video 1/1 (3/903) shinchan.mp4: 320x512 1 shinchans, Done. (0.033s)
# video 1/1 (4/903) shinchan.mp4: 320x512 1 shinchans, Done. (0.033s)
# video 1/1 (5/903) shinchan.mp4: 320x512 1 shinchans, Done. (0.027s)
# video 1/1 (6/903) shinchan.mp4: 320x512 1 shinchans, Done. (0.021s)
# video 1/1 (7/903) shinchan.mp4: 320x512 1 shinchans, Done. (0.021s)
# ...
